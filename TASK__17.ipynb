# %% [markdown]
# 1. Create a DataFrame by passing a random numpy array,with a datetie index and labelled columns.and display its,
#      - Head
#      - Tail
#      - Index
#      - Columns
#      - Values
#      - statistics

# %%
 import pandas as pd
import numpy as np
dates=pd.date_range('20201010',periods=6)
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
print(df)
print(df.head())
print(df.tail())
print(df.index)
print(df.columns)
print(df.values)
print(df.describe())
# Out:
#                    A         B         C         D
# 2020-10-10  1.539284 -0.400801 -0.758379 -0.475474
# 2020-10-11  0.411256 -0.141075  0.023831 -0.224338
# 2020-10-12 -0.978288 -0.638718  0.812847 -0.034053
# 2020-10-13  0.269438  1.973891 -1.740581 -0.307152
# 2020-10-14 -1.118635 -0.284388 -0.623106  1.778274
# 2020-10-15  0.777290 -0.923496  0.484798  0.576298
#                    A         B         C         D
# 2020-10-10  1.539284 -0.400801 -0.758379 -0.475474
# 2020-10-11  0.411256 -0.141075  0.023831 -0.224338
# 2020-10-12 -0.978288 -0.638718  0.812847 -0.034053
# 2020-10-13  0.269438  1.973891 -1.740581 -0.307152
# 2020-10-14 -1.118635 -0.284388 -0.623106  1.778274
#                    A         B         C         D
# 2020-10-11  0.411256 -0.141075  0.023831 -0.224338
# 2020-10-12 -0.978288 -0.638718  0.812847 -0.034053
# 2020-10-13  0.269438  1.973891 -1.740581 -0.307152
# 2020-10-14 -1.118635 -0.284388 -0.623106  1.778274
# 2020-10-15  0.777290 -0.923496  0.484798  0.576298
# DatetimeIndex(['2020-10-10', '2020-10-11', '2020-10-12', '2020-10-13',
#                '2020-10-14', '2020-10-15'],
#               dtype='datetime64[ns]', freq='D')
# Index(['A', 'B', 'C', 'D'], dtype='object')
# [[ 1.53928366 -0.40080115 -0.7583794  -0.47547386]
#  [ 0.41125596 -0.14107545  0.02383103 -0.2243377 ]
#  [-0.97828847 -0.63871838  0.81284738 -0.03405322]
#  [ 0.26943823  1.97389149 -1.74058144 -0.30715218]
#  [-1.11863537 -0.28438834 -0.62310585  1.77827366]
#  [ 0.77728995 -0.92349635  0.48479801  0.57629787]]
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.150057 -0.069098 -0.300098  0.218926
# std    1.028454  1.038251  0.932629  0.846015
# min   -1.118635 -0.923496 -1.740581 -0.475474
# 25%   -0.666357 -0.579239 -0.724561 -0.286449
# 50%    0.340347 -0.342595 -0.299637 -0.129195
# 75%    0.685781 -0.176904  0.369556  0.423710
# max    1.539284  1.973891  0.812847  1.778274

# %% [markdown]
# 2. Use the above table and,
#       - find transpose of your data.
#       - sort the index in the descending order of the date.

# %%
print(df.transpose())
print(df.sort_index (ascending=False))
# Out:
#    2020-10-10  2020-10-11  2020-10-12  2020-10-13  2020-10-14  2020-10-15
# A    1.539284    0.411256   -0.978288    0.269438   -1.118635    0.777290
# B   -0.400801   -0.141075   -0.638718    1.973891   -0.284388   -0.923496
# C   -0.758379    0.023831    0.812847   -1.740581   -0.623106    0.484798
# D   -0.475474   -0.224338   -0.034053   -0.307152    1.778274    0.576298
#                    A         B         C         D
# 2020-10-15  0.777290 -0.923496  0.484798  0.576298
# 2020-10-14 -1.118635 -0.284388 -0.623106  1.778274
# 2020-10-13  0.269438  1.973891 -1.740581 -0.307152
# 2020-10-12 -0.978288 -0.638718  0.812847 -0.034053
# 2020-10-11  0.411256 -0.141075  0.023831 -0.224338
# 2020-10-10  1.539284 -0.400801 -0.758379 -0.475474

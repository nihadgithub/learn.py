# %% [markdown]
# 1. Write a program to check whether a  string is palindrome or not using functions.
#
#    ( A function is to be created to check whether the string is palindrome and it should give the output true or false to the main program)

# %%
def palindrome(str):
    print(str==str[::-1])        
str = input("Enter any string to check whether palindrome or not : ")
palindrome(str)
# Out:
# Enter any string to check whether palindrome or not : abba
# True

# %% [markdown]
# 2.  Write a menu driven program to find largest element in L, smallest element, avg of all values, sum of all values in L. All these operation should be performed in different functions and the result should be returned.
#
#
#       L=[23,24,11,90,1,41,9,99,28,56,72]

# %%
2
3
1
L=[23,24,11,90,1,41,9,99,28,56,72]
 
def largest(L):
 
    max = L[0] 
 
    for x in L: 
 
        if x > max : 
 
             max = x 
 
    return max
 
def smallest(L):
 
    min = L[0] 
 
    for x in L: 
 
        if x <min : 
 
             min = x 
 
    return min
 
def Average(L):
 
    return sum(L) / len(L)
 
def sums(L):
 
    return sum(L)
 
    
 
while True:
 
    print ("___Menu___")
 
    print ("1. Largest number of L ")
 
    print ("2. Smallest number of L ")
 
    print ("3. Average of all numbers ")
 
    print ("4. Sum of all elements ")
 
    print("5. Exit")
 
    choice=int(input("Enter your choice : "))
 
    if(choice==1):
 
        print("largest number of L is",largest(L))
 
    elif(choice==2):
 
        print("smallest number of L is",smallest(L))
 
    elif (choice==3):
 
        print("Average of all the numbers in L",Average(L))
 
    elif(choice==4):
 
        print("Sum of all the numbers in L",sums(L))
 
    elif(choice==5):
 
        exit()
 
            
 
    else:
 
        print("wrong choice")
# Out:
# ___Menu___
# 1. Largest number of L
# 2. Smallest number of L
# 3. Average of all numbers
# 4. Sum of all elements
# 5. Exit
# Enter your choice : 1
# largest number of L is 99
# ___Menu___
# 1. Largest number of L
# 2. Smallest number of L
# 3. Average of all numbers
# 4. Sum of all elements
# 5. Exit
# Enter your choice : 2
# smallest number of L is 1
# ___Menu___
# 1. Largest number of L
# 2. Smallest number of L
# 3. Average of all numbers
# 4. Sum of all elements
# 5. Exit
# Enter your choice : 3
# Average of all the numbers in L 41.27272727272727
# ___Menu___
# 1. Largest number of L
# 2. Smallest number of L
# 3. Average of all numbers
# 4. Sum of all elements
# 5. Exit
# Enter your choice : 4
# Sum of all the numbers in L 454
# ___Menu___
# 1. Largest number of L
# 2. Smallest number of L
# 3. Average of all numbers
# 4. Sum of all elements
# 5. Exit
# Enter your choice : 5
# ___Menu___
# 1. Largest number of L
# 2. Smallest number of L
# 3. Average of all numbers
# 4. Sum of all elements
# 5. Exit

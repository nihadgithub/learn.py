# %% [markdown]
# 1. Create a DataFrame by passing a random numpy array,with a dateted index and labelled columns and display,
#   - where values of the column A is greater than 0.
#   - where values of the columns A is greater than 0 and B greater than -1.
#   - where values of the columns A  is greater than 0 or B greater than -1.

# %%
import pandas as pd
import numpy as np
dates=pd.date_range('20201010',periods=6)
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
print(df)
a=df[df.A>0]
print(a)
print(df[(df.A>0)&(df.B>-1)])
print(df[(df.A>0)|(df.B>-1)])
# Out:
#                    A         B         C         D
# 2020-10-10 -0.409658  0.769475  0.603221 -0.946457
# 2020-10-11 -0.216015  0.844195  0.466268  1.161980
# 2020-10-12 -0.390344  1.159722 -0.384219 -1.279560
# 2020-10-13  0.793579 -0.482918 -1.069623  0.016983
# 2020-10-14 -0.367051 -0.644138  0.674421 -1.398564
# 2020-10-15  0.273250 -0.984532  0.930775 -2.006560
#                    A         B         C         D
# 2020-10-13  0.793579 -0.482918 -1.069623  0.016983
# 2020-10-15  0.273250 -0.984532  0.930775 -2.006560
#                    A         B         C         D
# 2020-10-13  0.793579 -0.482918 -1.069623  0.016983
# 2020-10-15  0.273250 -0.984532  0.930775 -2.006560
#                    A         B         C         D
# 2020-10-10 -0.409658  0.769475  0.603221 -0.946457
# 2020-10-11 -0.216015  0.844195  0.466268  1.161980
# 2020-10-12 -0.390344  1.159722 -0.384219 -1.279560
# 2020-10-13  0.793579 -0.482918 -1.069623  0.016983
# 2020-10-14 -0.367051 -0.644138  0.674421 -1.398564
# 2020-10-15  0.273250 -0.984532  0.930775 -2.006560

# %% [markdown]
# 2. Create a DataFrame by passing a random numpy array,with a dateted index and labelled columns and check if ,
#   - the values of the table are greater the zero or not.
#   - the value at the postion (0,0) is equal to NaN or not.

# %%
 import pandas as pd
import numpy as np
dates=pd.date_range('20201010',periods=6)
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
print(df)
print(df>0)
df1=df.loc[dates[0],'A']
print(pd.isna(df1))
# Out:
#                    A         B         C         D
# 2020-10-10  1.083787 -1.061256 -0.042501  0.211235
# 2020-10-11 -0.142598  0.469786 -0.657870 -0.102352
# 2020-10-12 -0.880114 -0.106120  0.522523  0.877576
# 2020-10-13  0.112203 -0.625188  0.007201 -1.230581
# 2020-10-14  3.922152 -0.350455  0.442740  1.197767
# 2020-10-15 -1.141152  0.363169 -0.022724  0.901824
#                 A      B      C      D
# 2020-10-10   True  False  False   True
# 2020-10-11  False   True  False  False
# 2020-10-12  False  False   True   True
# 2020-10-13   True  False   True  False
# 2020-10-14   True  False   True   True
# 2020-10-15  False   True  False   True
# False

# %% [markdown]
# 3. Create a DataFrame by passing a random numpy array,with a dateted index and labelled columns and,
#   - reindex the index with even dates.
#   - create a column with values NaN.
#   - make the values of the first two index of the newly created column as 1

# %%
import pandas as pd
import numpy as np
dates=pd.date_range('20201010',periods=6)
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
print(df1)
df1=df.reindex(index=dates[::2],columns=list(df.columns))
print(df1.assign(E=np.nan))
df1.loc[dates[0]:dates[2],'E']=1
print(df1)
# Out:
# 1.0837873658683683
#                    A         B         C         D   E
# 2020-10-10 -0.684212  1.167094  0.036637 -0.880687 NaN
# 2020-10-12 -0.407567 -0.202539 -1.149534  1.294422 NaN
# 2020-10-14  1.317719 -2.888783  0.745969 -0.431473 NaN
#                    A         B         C         D    E
# 2020-10-10 -0.684212  1.167094  0.036637 -0.880687  1.0
# 2020-10-12 -0.407567 -0.202539 -1.149534  1.294422  1.0
# 2020-10-14  1.317719 -2.888783  0.745969 -0.431473  NaN

# %% [markdown]
# 1. In the data given below,
#   - find the boolean mask where value is nan
#   - remove the row with missing data.

# %%
import pandas as pd
import numpy as np
dates = pd.date_range('20210101',periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates,columns=list('ABCD'))
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))
df["F"]=s1
df1=df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df1
#please provide your answer below this line
print(df1.isnull())
print(df1.dropna(axis=0))
# Out:
#                 A      B      C      D     F      E
# 2021-01-01  False  False  False  False  True  False
# 2021-01-02  False  False  False  False  True  False
# 2021-01-03  False  False  False  False  True   True
# 2021-01-04  False  False  False  False  True   True
# Empty DataFrame
# Columns: [A, B, C, D, F, E]
# Index: []

# %% [markdown]
# 2. In the data given below,fill the missing data with 20.

# %%
import pandas as pd
import numpy as np
dates = pd.date_range('20210101',periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates,columns=list('ABCD'))
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))
df["F"]=s1
df1=df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df1
#please provide your answer below this line.
print(df1.fillna(value=20))
# Out:
#                    A         B         C         D     F     E
# 2021-01-01 -0.283766 -0.623180  1.875839 -0.755442  20.0   1.0
# 2021-01-02  0.333395 -1.886753  1.674696 -1.450377  20.0   1.0
# 2021-01-03  1.017220 -0.103959 -0.380062 -1.363442  20.0  20.0
# 2021-01-04 -1.194175  0.013127  0.950150 -0.425219  20.0  20.0

# %% [markdown]
# 3. From the data given below,
#   - break the data in to pieces from 0 t0 2 ,3 t0 7
#   - concatenate the pieces.
#   - concatenate the pieces along axis 1
#   - label each as 'a' and 'b' respectively and perform concatenation.

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(10, 4))
df
#please provide your answer below this line
pieces=[df[:3],df[3:8]]
print(pieces)
print(pd.concat(pieces))
print(pd.concat(pieces,axis=1))
a=df[:3]
b=df[3:8]
print(pd.concat([a,]))
# Out:
# [          0         1         2         3
# 0 -0.196078 -0.036091 -1.383781  0.609125
# 1 -2.225193  1.618026 -0.421675 -1.585261
# 2  0.878449 -0.509257 -0.298477 -1.625561,           0         1         2         3
# 3  0.088894 -0.483644  0.169248  1.220937
# 4 -0.564384  0.725712  0.635821 -0.089838
# 5 -0.084446 -0.352656 -0.496501 -0.591487
# 6  0.879759 -0.546933 -1.485918  1.045473
# 7  2.569163 -0.732790 -0.036477  0.168262]
#           0         1         2         3
# 0 -0.196078 -0.036091 -1.383781  0.609125
# 1 -2.225193  1.618026 -0.421675 -1.585261
# 2  0.878449 -0.509257 -0.298477 -1.625561
# 3  0.088894 -0.483644  0.169248  1.220937
# 4 -0.564384  0.725712  0.635821 -0.089838
# 5 -0.084446 -0.352656 -0.496501 -0.591487
# 6  0.879759 -0.546933 -1.485918  1.045473
# 7  2.569163 -0.732790 -0.036477  0.168262
#           0         1         2  ...         1         2         3
# 0 -0.196078 -0.036091 -1.383781  ...       NaN       NaN       NaN
# 1 -2.225193  1.618026 -0.421675  ...       NaN       NaN       NaN
# 2  0.878449 -0.509257 -0.298477  ...       NaN       NaN       NaN
# 3       NaN       NaN       NaN  ... -0.483644  0.169248  1.220937
# 4       NaN       NaN       NaN  ...  0.725712  0.635821 -0.089838
# 5       NaN       NaN       NaN  ... -0.352656 -0.496501 -0.591487
# 6       NaN       NaN       NaN  ... -0.546933 -1.485918  1.045473
# 7       NaN       NaN       NaN  ... -0.732790 -0.036477  0.168262
#
# [8 rows x 8 columns]
#           0         1         2         3
# 0 -0.196078 -0.036091 -1.383781  0.609125
# 1 -2.225193  1.618026 -0.421675 -1.585261
# 2  0.878449 -0.509257 -0.298477 -1.625561
